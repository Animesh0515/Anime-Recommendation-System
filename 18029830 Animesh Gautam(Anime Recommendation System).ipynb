# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv("E:/A.I/Coursework/New folder/anime.csv")
df.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
#Exploring the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   anime_id  12294 non-null  int64
#  1   name      12294 non-null  object
#  2   genre     12232 non-null  object
#  3   type      12269 non-null  object
#  4   episodes  12294 non-null  object
#  5   rating    12064 non-null  float64
#  6   members   12294 non-null  int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.5+ KB

# %%
# count the missing values in each column
df.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre        62
# type         25
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
#For this content based system we  will be using { Name, Genre, Type} column.

# %%
# preprocessing
#NaN=(None Value)Not a Number are special values in DataFrame and numpy arrays that represent the missing of value in a cell)
# filling NaN  with unknown
df.loc[(df['type'].isnull()), 'type'] = 'Unknown'## select value by row label and column label
df.loc[(df['genre'].isnull()), 'genre'] = 'Unknown'
#loc is used for indexing or selecting based on name .i.e. by row name and column name

# %%
df.isnull().sum()
# Out:
# anime_id      0
# name          0
# genre         0
# type          0
# episodes      0
# rating      230
# members       0
# dtype: int64

# %%
#Removing unwanted columns
df.drop(['rating', 'members', 'episodes'], axis=1, inplace=True)
#Axis 1 will work on all the COLUMNS in each ROW
#inplace=true performs operation on data and nothing is returned.
df.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type
# 0               Drama, Romance, School, Supernatural  Movie
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV
# 3                                   Sci-Fi, Thriller     TV
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV

# %%
# Converting to lower case
df['genre'] = df['genre'].apply(lambda x: " ".join(x.lower() for x in x.split()))

# %%
df['bag_of_words'] = ""
df.loc[:,'bag_of_words'] = df.loc[:, 'genre'] +', '+ df.loc[:, 'type']
#selecting all the values form genre and type and keeping them togther by sperating them with ','.

# %%
# Data after preprocessing
df.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type  \
# 0               drama, romance, school, supernatural  Movie
# 1  action, adventure, drama, fantasy, magic, mili...     TV
# 2  action, comedy, historical, parody, samurai, s...     TV
# 3                                   sci-fi, thriller     TV
# 4  action, comedy, historical, parody, samurai, s...     TV
#
#                                         bag_of_words
# 0        drama, romance, school, supernatural, Movie
# 1  action, adventure, drama, fantasy, magic, mili...
# 2  action, comedy, historical, parody, samurai, s...
# 3                               sci-fi, thriller, TV
# 4  action, comedy, historical, parody, samurai, s...

# %%
#Convert a collection of raw documents to a matrix of TF-IDF features
vectorizer = TfidfVectorizer()#word count of the words in the document
tfidf = vectorizer.fit_transform(df["bag_of_words"])#Converts into sparse matriz and the output of this comes as a sparse_matrix.

# %%
# Using Cosine to obtain similaritier between two animes
cosine_sim = cosine_similarity(tfidf, tfidf)

# %%
#recommender function
def recommendation(name, cosine_sim):
    recommended = np.array([])
    index_ = df.loc[(df['name'] == name)].index
    score = cosine_sim[index_]
    ind = np.argpartition(score[0], -10)[-11:]
    ind = ind[np.argsort(score[0][ind])]
    return ind

# %%
# Predicting movies similar to "Under the Dog"
indices = recommendation('Under the Dog', cosine_sim)
df[['anime_id','name', 'genre', 'type']].loc[indices]
# Out:
#       anime_id                                               name  \
# 7649      3064                                         Kizuoibito
# 493       5630                                    Higashi no Eden
# 6889     12723                                 Loups=Garous Pilot
# 5525      7598                                       Loups=Garous
# 5477     13863           Arve Rezzle: Kikaijikake no Yousei-tachi
# 2518      6610                                        Ibara no Ou
# 196      32188  Steins;Gate: Kyoukaimenjou no Missing Link - D...
# 126      10863              Steins;Gate: Oukoubakko no Poriomania
# 59       11577         Steins;Gate Movie: Fuka Ryouiki no Déjà vu
# 3         9253                                        Steins;Gate
# 5126     27387                                      Under the Dog
#
#                                                   genre     type
# 7649                action, adventure, seinen, thriller      OVA
# 493   action, comedy, drama, mystery, romance, sci-f...       TV
# 6889                          mystery, sci-fi, thriller  Special
# 5525                          mystery, sci-fi, thriller    Movie
# 5477           action, drama, mystery, sci-fi, thriller    Movie
# 2518                  action, mystery, sci-fi, thriller    Movie
# 196                                    sci-fi, thriller  Special
# 126                                    sci-fi, thriller  Special
# 59                                     sci-fi, thriller    Movie
# 3                                      sci-fi, thriller       TV
# 5126                           action, sci-fi, thriller      OVA

# %%
# Predicting movies similar to "Kizuoibito"
indices = recommendation('Kizuoibito', cosine_sim)
df[['anime_id','name', 'genre', 'type']].loc[indices]
# Out:
#       anime_id                                      name  \
# 4286      6736                   Mouryou no Hako Special
# 2199      4879                           Mouryou no Hako
# 53        6114       Rainbow: Nisha Rokubou no Shichinin
# 5126     27387                             Under the Dog
# 6689      1928                               Early Reins
# 7139     20329              Koroshiya-san: The Hired Gun
# 5297      2698                                 Sanctuary
# 6009       838  Narutaru: Mukuro Naru Hoshi Tama Taru Ko
# 353       5682          Phantom: Requiem for the Phantom
# 1254      4039                             Golgo 13 (TV)
# 7649      3064                                Kizuoibito
#
#                                            genre     type
# 4286     mystery, seinen, supernatural, thriller  Special
# 2199     mystery, seinen, supernatural, thriller       TV
# 53           drama, historical, seinen, thriller       TV
# 5126                    action, sci-fi, thriller      OVA
# 6689                   action, adventure, seinen      OVA
# 7139    action, comedy, police, seinen, thriller       TV
# 5297     action, drama, police, seinen, thriller      OVA
# 6009                     drama, seinen, thriller       TV
# 353              action, drama, seinen, thriller       TV
# 1254  action, adventure, drama, seinen, thriller       TV
# 7649         action, adventure, seinen, thriller      OVA
